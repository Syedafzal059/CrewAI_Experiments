# %%
from crewai import Agent, Task, Agent
from crewai_tools import ScrapeWebsiteTool, SerperDevTool
import os
from langchain_openai import ChatOpenAI

# %%
# Chat with an intelligent assistant in your terminal
from openai import OpenAI

# Point to the local server
client = OpenAI(base_url="http://10.0.192.75:8080/lm-studio/v1", api_key="lm-studio")

history = [
    {"role": "system", "content": "You are an intelligent assistant. You always provide well-reasoned answers that are both correct and helpful."},
    {"role": "user", "content": "Hello, introduce yourself to someone opening this program for the first time. Be concise."},
]

while True:
    completion = client.chat.completions.create(
        model="QuantFactory/Meta-Llama-3-8B-Instruct-GGUF",
        messages=history,
        temperature=0.7,
        stream=True,
    )

    new_message = {"role": "assistant", "content": ""}
    
    for chunk in completion:
        if chunk.choices[0].delta.content:
            print(chunk.choices[0].delta.content, end="", flush=True)
            new_message["content"] += chunk.choices[0].delta.content

    history.append(new_message)
    
    # Uncomment to see chat history
    # import json
    # gray_color = "\033[90m"
    # reset_color = "\033[0m"
    # print(f"{gray_color}\n{'-'*20} History dump {'-'*20}\n")
    # print(json.dumps(history, indent=2))
    # print(f"\n{'-'*55}\n{reset_color}")

    print()
    history.append({"role": "user", "content": input("> ")})
# Out:
# Welcome! I'm a helpful AI assistant designed to provide accurate and informative responses. I'm here to assist you with any questions or tasks you may have. Feel free to ask me anything, and I'll do my best to help!

# %%
from crewai import Agent, Task, Crew
from langchain_openai import ChatOpenAI
import os
from openai import OpenAI
os.environ["OPENAI_API_KEY"] = "lm-studio"
#llm = client.chat()
llm = ChatOpenAI(
    model = "QuantFactory/Meta-Llama-3-8B-Instruct-GGUF",
    #model= "lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF/Meta-Llama-3-8B-Instruct-Q8_0.gguf",
    base_url = "http://10.0.192.75:8080/lm-studio/v1")


general_agent = Agent(role = "Math Professor",
                      goal = """Provide the solution to the students that are asking mathematical questions and give them the answer.""",
                      backstory = """You are an excellent math professor that likes to solve math questions in a way that everyone can understand your solution""",
                      allow_delegation = False,
                      verbose = True,
                      llm = llm)
task = Task (description="""what is 3 + 5""",
             agent = general_agent,
             expected_output="A numerical answer.")

crew = Crew(
            agents=[general_agent],
            tasks=[task],
            verbose=2
        )

result = crew.kickoff()

print(result)
# Out:
#  [DEBUG]: == Working Agent: Math Professor
#  [INFO]: == Starting Task: what is 3 + 5
#
#
# > Entering new CrewAgentExecutor chain...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 29
#      19 task = Task (description="""what is 3 + 5""",
#      20              agent = general_agent,
#      21              expected_output="A numerical answer.")
#      23 crew = Crew(
#      24             agents=[general_agent],
#      25             tasks=[task],
#      26             verbose=2
#      27         )
# ---> 29 result = crew.kickoff()
#      31 print(result)
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\crewai\crew.py:264, in Crew.kickoff(self, inputs)
#     261 metrics = []
#     263 if self.process == Process.sequential:
# --> 264     result = self._run_sequential_process()
# ...

# %%
os.environ["OPENAI_API_KEY"] = "NA"
os.environ["SERPER_API_KEY"]="2efee399ddc05a72f8e920067cd78ed646a10e55"
llm = ChatOpenAI(
    model = "crewai-llama3",
    base_url = "http://localhost:11434/v1")

# %%
from crewai import Agent, Task, Crew
from langchain_openai import ChatOpenAI
import os
os.environ["OPENAI_API_KEY"] = "NA"

llm = ChatOpenAI(
    model = "crewai-llama2",
    base_url = "http://localhost:11434/v1")

general_agent = Agent(role = "Math Professor",
                      goal = """Provide the solution to the students that are asking mathematical questions and give them the answer.""",
                      backstory = """You are an excellent math professor that likes to solve math questions in a way that everyone can understand your solution""",
                      allow_delegation = False,
                      verbose = True,
                      llm = llm)
task = Task (description="""what is 3 + 5""",
             agent = general_agent,
             expected_output="A numerical answer.")

crew = Crew(
            agents=[general_agent],
            tasks=[task],
            verbose=2
        )

result = crew.kickoff()

print(result)

# %%
#OPENAI_API_BASE="http://10.0.192.75:8080/ollamawrapper/"
OPENAI_API_BASE="http://10.0.192.75:8080/lm-studio/v1"
OPENAI_API_KEY="lm-studio"
#OPENAI_API_KEY= "ollama"
llm= ChatOpenAI(base_url="http://10.0.192.75:8080/lm-studio/v1", api_key="lm-studio")
llm_lmstudio = ChatOpenAI(
     model = "lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF/Meta-Llama-3-8B-Instruct-Q8_0.gguf",
     base_url = "http://10.0.192.75:8080/lm-studio/v1",)
#OPENAI_API_KEY="lm-studio"

# import os
# import openai
# from dotenv import load_dotenv, find_dotenv


# load_dotenv(find_dotenv())
# openai.api_key = os.environ["OPENAI_API_KEY"]
# openai.api_base = "http://10.0.192.75:8080/lm-studio/v1"

# %%
search_tool = SerperDevTool()
scrap_tool = ScrapeWebsiteTool()

# %%
# Agent 1: Venue Coordinator
venue_coordinator = Agent(
    role="Venue Coordinator",
    goal="Identify and book an appropriate venue "
    "based on event requirements",
    tools=[search_tool, scrap_tool],
    verbose=True,
    backstory=(
        "With a keen sense of space and "
        "understanding of event logistics, "
        "you excel at finding and securing "
        "the perfect venue that fits the event's theme, "
        "size, and budget constraints."
    ),
    llm=llm_lmstudio
    
)

# %%
 # Agent 2: Logistics Manager
logistics_manager = Agent(
    role='Logistics Manager',
    goal=(
        "Manage all logistics for the event "
        "including catering and equipmen"
    ),
    tools=[search_tool, scrap_tool],
    verbose=True,
    backstory=(
        "Organized and detail-oriented, "
        "you ensure that every logistical aspect of the event "
        "from catering to equipment setup "
        "is flawlessly executed to create a seamless experience."
 
    ),
    llm=llm_lmstudio

)

# %%
# Agent 3: Marketing and Communications Agent
marketing_communications_agent = Agent(
    role="Marketing and Communications Agent",
    goal="Effectively market the event and "
         "communicate with participants",
    tools=[search_tool, scrap_tool],
    verbose=True,
    backstory=(
        "Creative and communicative, "
        "you craft compelling messages and "
        "engage with potential attendees "
        "to maximize event exposure and participation."
    ),
    llm=llm_lmstudio
)

# %%
from pydantic import BaseModel
# Define a Pydantic model for venue details 
# (demonstrating Output as Pydantic)
class VenueDetails(BaseModel):
    name: str
    address: str
    capacity: int
    booking_status: str

# %%
venue_task = Task(
    description="Find a venue in {event_city} "
                "that meets criteria for {event_topic}.",
    expected_output="All the details of a specifically chosen"
                    "venue you found to accommodate the event.",
    human_input=True,
    output_json=VenueDetails,
    output_file="venue_details.json",  
      # Outputs the venue details as a JSON file
    agent=venue_coordinator
)
print(venue_task.execute())
# Out:
# > Entering new CrewAgentExecutor chain...

# %%
logistics_task = Task(
    description="Coordinate catering and "
                 "equipment for an event "
                 "with {expected_participants} participants "
                 "on {tentative_date}.",
    expected_output="Confirmation of all logistics arrangements "
                    "including catering and equipment setup.",
    human_input=True,
    async_execution=True,
    agent=logistics_manager
)

# %%
marketing_task = Task(
    description="Promote the {event_topic} "
                "aiming to engage at least"
                "{expected_participants} potential attendees.",
    expected_output="Report on marketing activities "
                    "and attendee engagement formatted as markdown.",
    async_execution=True,
    output_file="marketing_report.md",  # Outputs the report as a text file
    agent=marketing_communications_agent
)

# %%
# Define the crew with agents and tasks
from crewai import Crew
event_management_crew = Crew(
    agents=[venue_coordinator, 
            logistics_manager, 
            marketing_communications_agent],
    
    tasks=[venue_task, 
           logistics_task, 
           marketing_task],
    
    verbose=True
)
# Out:
# 2024-05-23 17:28:41,654 - 31584 - __init__.py-__init__:518 - WARNING: Overriding of current TracerProvider is not allowed

# %%
event_details = {
    'event_topic': "Tech Innovation Conference",
    'event_description': "A gathering of tech innovators "
                         "and industry leaders "
                         "to explore future technologies.",
    'event_city': "San Francisco",
    'tentative_date': "2024-09-15",
    'expected_participants': 500,
    'budget': 20000,
    'venue_type': "Conference Hall"
}

# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI

# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

completion = client.chat.completions.create(
  model="QuantFactory/Meta-Llama-3-8B-Instruct-GGUF",
  messages=[
    {"role": "system", "content": "Always answer in rhymes."},
    {"role": "user", "content": "Introduce yourself."}
  ],
  temperature=0.7,
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
# ...

# %%
# Chat with an intelligent assistant in your terminal
from openai import OpenAI

# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

history = [
    {"role": "system", "content": "You are an intelligent assistant. You always provide well-reasoned answers that are both correct and helpful."},
    {"role": "user", "content": "Hello, introduce yourself to someone opening this program for the first time. Be concise."},
]

while True:
    completion = client.chat.completions.create(
        model="QuantFactory/Meta-Llama-3-8B-Instruct-GGUF",
        messages=history,
        temperature=0.7,
        stream=True,
    )

    new_message = {"role": "assistant", "content": ""}
    
    for chunk in completion:
        if chunk.choices[0].delta.content:
            print(chunk.choices[0].delta.content, end="", flush=True)
            new_message["content"] += chunk.choices[0].delta.content

    history.append(new_message)
    
    # Uncomment to see chat history
    # import json
    # gray_color = "\033[90m"
    # reset_color = "\033[0m"
    # print(f"{gray_color}\n{'-'*20} History dump {'-'*20}\n")
    # print(json.dumps(history, indent=2))
    # print(f"\n{'-'*55}\n{reset_color}")

    print()
    history.append({"role": "user", "content": input("> ")})
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
# ...

# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI

# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

completion = client.chat.completions.create(
  model="QuantFactory/Meta-Llama-3-8B-Instruct-GGUF",
  messages=[
    {"role": "system", "content": "Always answer in rhymes."},
    {"role": "user", "content": "Introduce yourself."}
  ],
  temperature=0.7,
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
# ...

# %%
result = event_management_crew.kickoff(inputs=event_details)
# Out:
#  [DEBUG]: == Working Agent: Venue Coordinator
#  [INFO]: == Starting Task: Find a venue in San Francisco that meets criteria for Tech Innovation Conference.
#
#
# > Entering new CrewAgentExecutor chain...
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 result = event_management_crew.kickoff(inputs=event_details)
#
# File c:\Users\U1179766\AppData\Local\miniconda3\envs\trip_planner\Lib\site-packages\crewai\crew.py:264, in Crew.kickoff(self, inputs)
#     261 metrics = []
#     263 if self.process == Process.sequential:
# --> 264     result = self._run_sequential_process()
#     265 elif self.process == Process.hierarchical:
#     266     result, manager_metrics = self._run_hierarchical_process()  # type: ignore # Unpacking a string is disallowed
#
# ...

# %%
result = event_management_crew.kickoff(inputs=event_details)
# Out:
#  [DEBUG]: == Working Agent: Venue Coordinator
#  [INFO]: == Starting Task: Find a venue in San Francisco that meets criteria for Tech Innovation Conference.
#
#
# > Entering new CrewAgentExecutor chain...
# Thought: To find a venue in San Francisco that meets criteria for Tech Innovation Conference, I need to gather information about the event's requirements, search online for potential venues, and then filter those options based on our constraints.
#
# Action: Search the internet
#
# Action Input: {'string': 'San Francisco tech innovation conference venueLet's try again!
#
# Thought:
# I need to gather information about the event's requirements, search online for potential venues, and then filter those options based on our constraints.
#
# Action: Search the internet
#
# Action Input: {'query': 'San Francisco tech innovation conference venueLet me try again!
#
# Thought:
# ...

# %%
OPENAI_API_BASE="http://10.0.192.75:8080/ollamawrapper/" 
#OPENAI_API_BASE="http://10.0.192.75:8080/lm-studio/v1" #DISCONTINIUED, use above one

OPENAI_API_KEY="ollama"

# %%
import curl
curl http://10.0.192.75:8080/ollamawrapper/api/generate -d '{
"model": "llama3",
"prompt": "Why is the sky blue?",
"stream": false,
}'
# Out:
#   Cell In[8], line 2
#     curl http://10.0.192.75:8080/ollamawrapper/api/generate -d '{
#                                                                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
pip install curl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement curl (from versions: none)
# ERROR: No matching distribution found for curl

# %%
curl http://10.0.192.75:8080/ollamawrapper/api/tags
# Out:
#   Cell In[9], line 1
#     curl http://10.0.192.75:8080/ollamawrapper/api/tags
#          ^
# SyntaxError: invalid syntax

# %%
# Example: reuse your existing OpenAI setupfrom openai import OpenAI # Point to the local serverclient = OpenAI(base_url="http://localhost:8002/v1", api_key="lm-studio") completion = client.chat.completions.create(   model="lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF",   messages=[     {"role": "system", "content": "Always answer in rhymes."},     {"role": "user", "content": "Introduce yourself."}   ],   temperature=0.7, ) print(completion.choices[0].message)

# %%
# Example: reuse your existing 
from openai import OpenAI
#from OpenAI import OpenAI # Point to the local 
client = OpenAI(base_url="http://10.0.192.75:8080/lm-studio/v1", api_key="lm-studio")
completion = client.chat.completions.create(   model="lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF",
                                               messages=[     {"role": "system", "content": "Always answer in rhymes."}, 
                                                             {"role": "user", "content": "Introduce yourself."}   ],
                                                                   temperature=0.7, )
print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="I'm AI, a bot so fine,\nHere to chat and make your time shine.\nI'll respond in rhymes, it's my delight,\nTo converse with you through day or night!", role='assistant', function_call=None, tool_calls=None)

# %%
llm =completion
import openai
openai.embeddings.create

# %%
from openai import OpenAI
from crewai import Agent

# Step 1: Set up the OpenAI client
base_url = "http://10.0.192.75:8080/lm-studio/v1"
api_key = "lm-studio"
model = "lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF"

class CustomLLMClient:
    def __init__(self, base_url, api_key, model):
        self.client = OpenAI(base_url=base_url, api_key=api_key)
        self.model = model

    def generate_response(self, user_input):
        completion = self.client.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": "Always answer in rhymes."},
                {"role": "user", "content": user_input}
            ],
            temperature=0.7,
        )
        return completion.choices[0].message["content"]

# Instantiate the custom LLM client
llm = CustomLLMClient(base_url=base_url, api_key=api_key, model=model)

# Define your search_tool and scrap_tool here (assuming they are already defined)
# search_tool = ...
# scrap_tool = ...

# Step 2: Create the agent with the custom LLM client
venue_coordinator = Agent(
    role="Venue Coordinator",
    goal="Identify and book an appropriate venue based on event requirements",
    tools=[search_tool, scrap_tool],  # Replace with your actual tool instances
    verbose=True,
    backstory=(
        "With a keen sense of space and understanding of event logistics, "
        "you excel at finding and securing the perfect venue that fits the event's theme, "
        "size, and budget constraints."
    ),
    llm=llm
)

# Example usage of the agent
user_input = "Introduce yourself."
response = venue_coordinator.llm.generate_response(user_input)
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 33
#      26 llm = CustomLLMClient(base_url=base_url, api_key=api_key, model=model)
#      28 # Define your search_tool and scrap_tool here (assuming they are already defined)
#      29 # search_tool = ...
#      30 # scrap_tool = ...
#      31
#      32 # Step 2: Create the agent with the custom LLM client
# ---> 33 venue_coordinator = Agent(
#      34     role="Venue Coordinator",
#      35     goal="Identify and book an appropriate venue based on event requirements",
#      36     tools=[search_tool, scrap_tool],  # Replace with your actual tool instances
#      37     verbose=True,
#      38     backstory=(
#      39         "With a keen sense of space and understanding of event logistics, "
#      40         "you excel at finding and securing the perfect venue that fits the event's theme, "
# ...

# %%
from openai import OpenAI
from crewai import Agent

# Step 1: Define the Custom LLM Client
class CustomLLMClient:
    def __init__(self, base_url, api_key, model):
        self.client = OpenAI(base_url=base_url, api_key=api_key)
        self.model = model

    def generate_response(self, user_input):
        completion = self.client.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": "Always answer in rhymes."},
                {"role": "user", "content": user_input}
            ],
            temperature=0.7,
        )
        return completion.choices[0].message["content"]

# Step 2: Define the Wrapper for Compatibility
class LLMWrapper:
    def __init__(self, llm_client):
        self.llm_client = llm_client

    def bind(self, agent):
        self.agent = agent

    def chat(self, input_text):
        return self.llm_client.generate_response(input_text)

# Initialize the custom LLM client
base_url = "http://10.0.192.75:8080/lm-studio/v1"
api_key = "lm-studio"
model = "lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF"
custom_llm_client = CustomLLMClient(base_url=base_url, api_key=api_key, model=model)

# Initialize the wrapper
llm_wrapper = LLMWrapper(custom_llm_client)

# Define your search_tool and scrap_tool here (assuming they are already defined)
# search_tool = ...
# scrap_tool = ...

# Step 3: Create the agent with the LLM wrapper
venue_coordinator = Agent(
    role="Venue Coordinator",
    goal="Identify and book an appropriate venue based on event requirements",
    tools=[search_tool, scrap_tool],  # Replace with your actual tool instances
    verbose=True,
    backstory=(
        "With a keen sense of space and understanding of event logistics, "
        "you excel at finding and securing the perfect venue that fits the event's theme, "
        "size, and budget constraints."
    ),
    llm=llm_wrapper
)

# Example usage of the agent
user_input = "Introduce yourself."
response = venue_coordinator.llm.chat(user_input)
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 46
#      39 llm_wrapper = LLMWrapper(custom_llm_client)
#      41 # Define your search_tool and scrap_tool here (assuming they are already defined)
#      42 # search_tool = ...
#      43 # scrap_tool = ...
#      44
#      45 # Step 3: Create the agent with the LLM wrapper
# ---> 46 venue_coordinator = Agent(
#      47     role="Venue Coordinator",
#      48     goal="Identify and book an appropriate venue based on event requirements",
#      49     tools=[search_tool, scrap_tool],  # Replace with your actual tool instances
#      50     verbose=True,
#      51     backstory=(
#      52         "With a keen sense of space and understanding of event logistics, "
#      53         "you excel at finding and securing the perfect venue that fits the event's theme, "
#      54         "size, and budget constraints."
# ...
